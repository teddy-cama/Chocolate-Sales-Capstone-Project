# %%
import seaborn as sns
import pandas as pd

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[(tips['size']==2) & (tips['sex']=='Female')]['total_bill'].mean()
#& (tips['sex']=='Male')]tips['total_bill'].mean()
# Out:
# 15.339482758620688

# %%
tp = tips.pivot_table(index='size',columns='sex',values='total_bill',observed=False)
#tp.rename()

# %%
tp
# Out:
# sex        Male     Female
# size
# 1      8.580000   6.796667
# 2     17.104082  15.339483
# 3     24.287083  21.547143
# 4     28.078214  30.278889
# 5     30.122500  29.850000
# 6     41.235000  28.425000

# %%
tp.rename(mapper={'Male':'Male Average','Female':'Female Average'},axis=1,inplace=True)

# %%
tp
# Out:
# sex   Male Average  Female Average
# size
# 1         8.580000        6.796667
# 2        17.104082       15.339483
# 3        24.287083       21.547143
# 4        28.078214       30.278889
# 5        30.122500       29.850000
# 6        41.235000       28.425000

# %% [markdown]
# # Personal Capstone Project

# %% [markdown]
# Alright, let's treat this like a data analysis project. You've got a CSV file with product information, and there are many things we can do with it! Here's a breakdown of potential operations and analysis, as if I were your "boss" giving you tasks:
#
# **Phase 1: Data Exploration and Cleaning (Essential First Steps)**
#
# 1.  **"First, I need you to understand the data. Load the CSV and give me a summary of each column. Tell me the data type, the number of missing values, and the number of unique values for each field."**
#     * This involves using Python libraries like Pandas to read the CSV and perform basic data inspection.
#     * Essentially, you'll need to use functions like `df.info()`, `df.isnull().sum()`, and `df.nunique()`.
#
# 2.  **"Next, we need to clean the data. Handle the missing values appropriately. For numeric fields like 'Price' and 'Stock', consider imputation or removal. For categorical fields like 'Color' or 'Category', decide on a strategy (e.g., fill with 'Unknown' or remove rows)."**
#     * This requires you to make decisions based on the context.
#     * Imputation (filling missing values) can be done using mean, median, or mode.
#     * Removing rows with many missing values might be necessary.
#
# 3.  **"Check for inconsistencies in the 'Currency' and 'Price' fields. Ensure all prices are in a consistent currency (e.g., convert all prices to USD if necessary). Also, clean up any text fields like 'Description' or 'Name' by removing unnecessary whitespace or special characters."**
#     * This step ensures data quality and consistency.
#     * You might need to write functions to clean text.
#     * You might need to use external api's to convert currency.
#
# 4.  **"Examine the 'Stock' and 'Availability' fields. Are they consistent? Do they provide redundant information? If so, decide which field is more reliable and consider removing the other."**
#     * Sometimes, multiple fields convey similar information.
#
# **Phase 2: Basic Analysis and Reporting**
#
# 5.  **"Provide a summary report of the distribution of products across different 'Categories' and 'Brands'. Show me the top 5 categories and brands with the highest product counts."**
#     * This involves using `value_counts()` and plotting libraries like Matplotlib or Seaborn.
#
# 6.  **"Analyze the 'Price' distribution. Calculate the mean, median, and standard deviation of prices. Create a histogram to visualize the price distribution. Identify any outliers."**
#     * This helps understand the pricing strategy and identify potential errors.
#
# 7.  **"Investigate the relationship between 'Category' and 'Price'. Are there any categories with significantly higher or lower average prices? Create box plots to visualize this relationship."**
#     * This helps understand pricing per category.
#
# 8.  **"Show me the stock levels for each brand. Which brands have the most stock? Which brands have the least stock?"**
#     * Helps understand inventory per brand.
#
# **Phase 3: Advanced Analysis (If Time Permits)**
#
# 9.  **"Perform a correlation analysis between numeric fields like 'Price' and 'Stock'. Is there any relationship between these variables?"**
#     * This helps understand potential correlations.
#
# 10. **"Analyze the 'Description' field using text analysis techniques. Identify the most common keywords or phrases used in product descriptions. This can help us understand customer preferences."**
#     * This requires Natural Language Processing (NLP) techniques.
#
# 11. **"Create a dashboard that summarizes key metrics, such as total product count, average price, and stock levels. Include visualizations of product distribution across categories and brands."**
#     * This helps present the findings in a clear and concise manner.
#
# **Example Python Code Snippets (Illustrative)**
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the CSV
# df = pd.read_csv("your_file.csv")
#
# # 1. Summary of each column
# print(df.info())
# print(df.isnull().sum())
# print(df.nunique())
#
# # 2. Handle missing values (example)
# df['Price'].fillna(df['Price'].median(), inplace=True)
# df['Color'].fillna('Unknown', inplace=True)
#
# # 5. Category and brand distribution
# print(df['Category'].value_counts().head(5))
# print(df['Brand'].value_counts().head(5))
#
# # 6. Price distribution
# print(df['Price'].describe())
# plt.hist(df['Price'])
# plt.show()
#
# # 7. Category vs. Price
# sns.boxplot(x='Category', y='Price', data=df)
# plt.xticks(rotation=90)
# plt.show()
#
# # 8. Stock per brand.
# print(df.groupby('Brand')['Stock'].sum().sort_values(ascending = False))
# ```
#
# **Remember:**
#
# * Replace `"your_file.csv"` with the actual filename.
# * These are just starting points. Adapt them to your specific needs.
# * Document your steps and findings clearly.
#
# Let me know when you've uploaded the file, and we can dive deeper into the specific tasks!

# %%
df = pd.read_csv('Chocolate Sales.csv')

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# 3               342
# 4               184
# ...             ...
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344
#
# [1094 rows x 6 columns]

# %%
df['Integer Amount']=df['Amount'].apply(lambda x: x.split('$')[1])
#We create a new column and make it all teh currency values without the dollar sign
# WIth lambda, we eliminate the dollar sign from all values

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped Integer Amount
# 0               180         5,320
# 1                94         7,896
# 2                91         4,501
# 3               342        12,726
# 4               184        13,685
# ...             ...            ...
# 1089            323         4,410
# 1090            119         6,559
# 1091            217           574
# 1092            384         2,086
# 1093            344         5,075
#
# [1094 rows x 7 columns]

# %%
df['Integer Amount'] = df['Integer Amount'].str.replace(',','').str.strip()
#Replaces the comma(',') with space, then removes the space.
#done to ensure amount can be converted to integers.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Integer Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df['Integer Amount'] = df['Integer Amount'].str.replace(',','').str.strip()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Integer Amount'

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped Integer Amount
# 0               180           5320
# 1                94           7896
# 2                91           4501
# 3               342          12726
# 4               184          13685
# ...             ...            ...
# 1089            323           4410
# 1090            119           6559
# 1091            217            574
# 1092            384           2086
# 1093            344           5075
#
# [1094 rows x 7 columns]

# %%
df['Integer Amount']=df['Integer Amount'].apply(lambda x: int(x))
#Convert

# %%
df['Amount'] = df['Integer Amount']

# %%
df
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22    5320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22    4410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22    5075
#
#       Boxes Shipped  Integer Amount
# 0               180            5320
# 1                94            7896
# 2                91            4501
# 3               342           12726
# 4               184           13685
# ...             ...             ...
# 1089            323            4410
# 1090            119            6559
# 1091            217             574
# 1092            384            2086
# 1093            344            5075
#
# [1094 rows x 7 columns]

# %%
df.rename(mapper={'Integer Amount':'Currency'},axis=1,inplace=True)

# %%
df['Currency'] = 'Dollars($)'

# %%
df
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22    5320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22    4410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22    5075
#
#       Boxes Shipped    Currency
# 0               180  Dollars($)
# 1                94  Dollars($)
# 2                91  Dollars($)
# 3               342  Dollars($)
# 4               184  Dollars($)
# ...             ...         ...
# 1089            323  Dollars($)
# 1090            119  Dollars($)
# 1091            217  Dollars($)
# 1092            384  Dollars($)
# 1093            344  Dollars($)
#
# [1094 rows x 7 columns]

# %%
df[df['Amount']==df['Amount'].max()]
# The person with the highest Purchase price
# Out:
#      Sales Person Country              Product       Date  Amount  \
# 543  Ches Bonnell   India  Peanut Butter Cubes  27-Jan-22   22050
#
#      Boxes Shipped    Currency
# 543            208  Dollars($)

# %%
hmp = df.pivot_table(index='Product',columns='Country',values='Amount')
#TO create a table that shows the average purchase price (amount) of different brands by country.

# %%
sns.heatmap(hmp,cmap='coolwarm',robust=True)
# Out:
# <Axes: xlabel='Country', ylabel='Product'>

# %% [markdown]
# Excellent! You've provided a clear summary of your sales data. Let's get to work. Here are a bunch of tasks to analyze your sales data, structured to build your skills progressively:
#
# **Phase 1: Basic Exploration and Cleaning**
#
# 1.  **"Convert the 'Date' column to datetime objects. This will allow us to perform time-based analysis. Then tell me the earliest and latest date in the dataset."**
#     * Use `pd.to_datetime()` to convert the column.
#     * Use `.min()` and `.max()` on the datetime column.
#
# 2.  **"Check for unique values in the 'Country', 'Product', and 'Sales Person' columns. How many unique values are there in each column?"**
#     * Use `.nunique()` to get the count.
#     * Use `.unique()` to see the unique values themselves if needed.
#
# 3.  **"Analyze the 'Amount' and 'Boxes Shipped' columns. Calculate the descriptive statistics (mean, median, standard deviation, min, max, etc.). Are there any outliers?"**
#     * Use `.describe()` to get the statistics.
#     * Use histograms or box plots to visualize the distributions and identify outliers.
#
# 4.  **"Check for any inconsistencies in the 'Currency' column. Are all transactions in the same currency? If not, investigate and handle the differences if needed. If there are multiple currencies, inform me of the conversion rates to a single currency, for example, USD."**
#     * Use `.unique()` and `.value_counts()` to understand the currencies.
#
# 5.  **"Create a new column called 'Amount per Box' by dividing the 'Amount' column by the 'Boxes Shipped' column. Then analyze the distribution of this new column."**
#     * This helps understand the price per box.
#
# **Phase 2: Basic Analysis and Reporting**
#
# 6.  **"Calculate the total sales 'Amount' and 'Boxes Shipped' for each 'Country'. Which country has the highest sales? Which country has the most boxes shipped?"**
#     * Use `groupby()` and `sum()`.
#
# 7.  **"Calculate the total sales 'Amount' and 'Boxes Shipped' for each 'Product'. Which product is the best seller in terms of amount? Which product has the highest number of boxes shipped?"**
#     * Use `groupby()` and `sum()`.
#
# 8.  **"Calculate the total sales 'Amount' and 'Boxes Shipped' for each 'Sales Person'. Who is the top sales person?"**
#     * Use `groupby()` and `sum()`.
#
# 9.  **"Analyze sales over time. Calculate the total sales 'Amount' per month. Create a line plot to visualize the trend."**
#     * Extract the month from the 'Date' column.
#     * Use `groupby()` and `sum()`.
#     * Use `matplotlib` or `seaborn` for plotting.
#
# 10. **"Analyze sales by 'Country' and 'Product'. Create a pivot table or a grouped bar chart to visualize the sales 'Amount' for each product in each country."**
#     * Use `pivot_table()` or `groupby()` and `unstack()`.
#
# **Phase 3: Advanced Analysis (If Time Permits)**
#
# 11. **"Calculate the average 'Amount per Box' for each 'Product' and 'Country'. Are there any significant differences in price per box across different regions or products?"**
#     * Use `groupby()` and `mean()`.
#
# 12. **"Perform a time series analysis to identify any seasonal patterns or trends in sales. Decompose the time series into trend, seasonality, and residual components."**
#     * Use `statsmodels` library for time series decomposition.
#
# 13. **"Identify the top 3 Sales Persons in each country based on sales amount. Produce a table that shows this information."**
#     * Use `groupby()`, `apply()`, and `nlargest()`.
#
# 14. **"Create a dashboard that summarizes the key findings. Include visualizations of sales by country, product, and sales person, as well as the time series analysis."**
#     * Consider using libraries like `plotly` or `dash` for interactive dashboards.
#
# **Example Python Code Snippets (Illustrative)**
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the data
# df = pd.read_csv("your_sales_data.csv")
#
# # 1. Convert 'Date' to datetime
# df['Date'] = pd.to_datetime(df['Date'])
# print(df['Date'].min(), df['Date'].max())
#
# # 2. Unique values
# print(df['Country'].nunique())
# print(df['Product'].nunique())
# print(df['Sales Person'].nunique())
#
# # 3. Descriptive statistics
# print(df[['Amount', 'Boxes Shipped']].describe())
#
# # 6. Sales by country
# print(df.groupby('Country')[['Amount', 'Boxes Shipped']].sum())
#
# # 9. Sales over time
# df['Month'] = df['Date'].dt.to_period('M')
# monthly_sales = df.groupby('Month')['Amount'].sum()
# plt.plot(monthly_sales.index.astype(str), monthly_sales.values)
# plt.xticks(rotation=45)
# plt.show()
# ```
#
# Remember to replace `"your_sales_data.csv"` with your actual filename. Let me know how it goes and if you have any questions!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   int64
#  5   Boxes Shipped  1094 non-null   int64
#  6   Currency       1094 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 60.0+ KB

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22    5320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22   13685
#
#    Boxes Shipped    Currency
# 0            180  Dollars($)
# 1             94  Dollars($)
# 2             91  Dollars($)
# 3            342  Dollars($)
# 4            184  Dollars($)

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
#Convert dates from "04-Jan-22" to a workable python format

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency
# 0            180  Dollars($)
# 1             94  Dollars($)
# 2             91  Dollars($)
# 3            342  Dollars($)
# 4            184  Dollars($)

# %% [markdown]
# ## Earliest Purchase

# %%
df['Date'].min()
# Out:
# Timestamp('2022-01-03 00:00:00')

# %% [markdown]
# ## Latest Purchase

# %%
df['Date'].max()
# Out:
# Timestamp('2022-08-31 00:00:00')

# %% [markdown]
# ## Country Count, Product COunt, and Sales Person Count

# %%
df['Country'].nunique()
# Out:
# 6

# %%
pd.Series(df['Country'].unique())
# Out:
# 0             UK
# 1          India
# 2      Australia
# 3    New Zealand
# 4            USA
# 5         Canada
# dtype: object

# %%
df['Product'].nunique()
# Out:
# 22

# %%
pd.Series(df['Product'].unique())
# Out:
# 0          Mint Chip Choco
# 1            85% Dark Bars
# 2      Peanut Butter Cubes
# 3       Smooth Sliky Salty
# 4          99% Dark & Pure
# 5              After Nines
# 6           50% Dark Bites
# 7             Orange Choco
# 8                  Eclairs
# 9            Drinking Coco
# 10     Organic Choco Syrup
# 11               Milk Bars
# 12     Spicy Special Slims
# 13        Fruit & Nut Bars
# 14              White Choc
# 15      Manuka Honey Choco
# 16            Almond Choco
# 17         Raspberry Choco
# 18    Choco Coated Almonds
# 19     Baker's Choco Chips
# 20    Caramel Stuffed Bars
# 21          70% Dark Bites
# dtype: object

# %%
df['Sales Person'].nunique()
# Out:
# 25

# %%
pd.Series(df['Sales Person'].unique())
# Out:
# 0          Jehu Rudeforth
# 1             Van Tuxwell
# 2            Gigi Bohling
# 3            Jan Morforth
# 4              Oby Sorrel
# 5         Gunar Cockshoot
# 6             Brien Boise
# 7     Rafaelita Blaksland
# 8            Barr Faughny
# 9          Mallorie Waber
# 10       Karlen McCaffrey
# 11         Marney O'Breen
# 12         Beverie Moffet
# 13        Roddy Speechley
# 14         Curtice Advani
# 15           Husein Augar
# 16            Kaine Padly
# 17    Dennison Crosswaite
# 18         Wilone O'Kielt
# 19         Andria Kimpton
# 20          Kelci Walkden
# 21         Camilla Castle
# 22        Madelene Upcott
# 23         Dotty Strutley
# 24           Ches Bonnell
# dtype: object

# %% [markdown]
# ## Statistical Description of Amount and Boxes Shipped

# %%
df['Amount'].describe()
# Out:
# count     1094.000000
# mean      5652.308044
# std       4102.442014
# min          7.000000
# 25%       2390.500000
# 50%       4868.500000
# 75%       8027.250000
# max      22050.000000
# Name: Amount, dtype: float64

# %%
df['Boxes Shipped'].describe()
# Out:
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000
# Name: Boxes Shipped, dtype: float64

# %%
sns.lmplot(x='Amount',y='Boxes Shipped',data=df,hue='Product',row='Country')

# %%
df[(df['Country']=='USA') & (df['Amount']==df['Amount'].min())]['Product']
# Out:
# Series([], Name: Product, dtype: object)

# %% [markdown]
# ## So, we want to see which product is least sold in the USA. First, we need a dataframe because the least sold product isn't in teh USA. We create a dataframe for USA's Products, their prices and amounts.
#
# # Wait for the big **OR**

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency
# 0            180  Dollars($)
# 1             94  Dollars($)
# 2             91  Dollars($)
# 3            342  Dollars($)
# 4            184  Dollars($)

# %%
USA_Brand = df[df['Country'] == 'USA']['Product']
USA_Amount = df[df['Country'] == 'USA']['Amount']
USA_Shippings = df[df['Country'] == 'USA']['Boxes Shipped']

# %%
USA_Brand
# Out:
# 11             Orange Choco
# 17       Smooth Sliky Salty
# 21      Spicy Special Slims
# 22              After Nines
# 27                  Eclairs
#                ...
# 1062         70% Dark Bites
# 1064         70% Dark Bites
# 1081     Smooth Sliky Salty
# 1082        Raspberry Choco
# 1090             White Choc
# Name: Product, Length: 179, dtype: object

# %%
usa = pd.DataFrame({'USABrand':USA_Brand,'USAAmount':USA_Amount,'USAShippings':USA_Shippings})

# %%
usa.head()
# Out:
#                USABrand  USAAmount  USAShippings
# 11         Orange Choco       3703            11
# 17   Smooth Sliky Salty       3017           140
# 21  Spicy Special Slims       1267           157
# 22          After Nines       4753           163
# 27              Eclairs       4025           112

# %%
usa[usa['USAAmount'] == usa['USAAmount'].min()]['USABrand']
# Out:
# 250    50% Dark Bites
# Name: USABrand, dtype: object

# %% [markdown]
# # That's ONe way to do it.

# %% [markdown]
# # THE BIG **OR**

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency
# 0            180  Dollars($)
# 1             94  Dollars($)
# 2             91  Dollars($)
# 3            342  Dollars($)
# 4            184  Dollars($)

# %%
df.groupby('Country')['Amount'].min()
# The idea is to first groupby country, then find the minimum amount by country.
# Out:
# Country
# Australia       63
# Canada         210
# India           28
# New Zealand      7
# UK               7
# USA             70
# Name: Amount, dtype: int64

# %%
df[(df['Country']=='USA') & (df['Amount']==70)]['Product']
# You get? It's shorter and more efficient to an extent.
# Out:
# 250    50% Dark Bites
# Name: Product, dtype: object

# %% [markdown]
# # Back To Our Boss's Report (Gemini)

# %% [markdown]
# ## Create a column to understand the price per box

# %%
df.head(2)
# Out:
#      Sales Person Country          Product       Date  Amount  Boxes Shipped  \
# 0  Jehu Rudeforth      UK  Mint Chip Choco 2022-01-04    5320            180
# 1     Van Tuxwell   India    85% Dark Bars 2022-08-01    7896             94
#
#      Currency
# 0  Dollars($)
# 1  Dollars($)

# %%
df['Amount Per Box'] = df['Amount']/df['Boxes Shipped']

# %%
df
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1          Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped    Currency  Amount Per Box
# 0               180  Dollars($)       29.555556
# 1                94  Dollars($)       84.000000
# 2                91  Dollars($)       49.461538
# 3               342  Dollars($)       37.210526
# 4               184  Dollars($)       74.375000
# ...             ...         ...             ...
# 1089            323  Dollars($)       13.653251
# 1090            119  Dollars($)       55.117647
# 1091            217  Dollars($)        2.645161
# 1092            384  Dollars($)        5.432292
# 1093            344  Dollars($)       14.752907
#
# [1094 rows x 8 columns]

# %% [markdown]
# ## Groupinng by Country with highest sales and shipments

# %%
countrySales['Country'] = df.groupby('Country')['Amount'].sum().max()

# %%
countrySales
# Out:
# Country
# Australia      1137367
# Canada          962899
# India          1045800
# New Zealand     950418
# UK             1051792
# USA            1035349
# Country        1137367
# Name: Amount, dtype: int64

# %%
countrySales.max()
# Out:
# 1137367

# %% [markdown]
# **Austalia's Got the Highest Sales**

# %%
df.groupby('Country')['Boxes Shipped'].sum()
# Out:
# Country
# Australia      32647
# Canada         31221
# India          29470
# New Zealand    26580
# UK             30265
# USA            26824
# Name: Boxes Shipped, dtype: int64

# %% [markdown]
# ## Problem: Doesn't arracnge according to highest first

# %% [markdown]
# **So, Australia's got the highest in shipment and total sales**

# %% [markdown]
# ## Best Selling Product by Amount and Shipments

# %%
df.groupby('Product')['Boxes Shipped'].sum()
# Out:
# Product
# 50% Dark Bites          9792
# 70% Dark Bites          8015
# 85% Dark Bars           7793
# 99% Dark & Pure         8127
# After Nines             8257
# Almond Choco            6736
# Baker's Choco Chips     6998
# Caramel Stuffed Bars    8717
# Choco Coated Almonds    6464
# Drinking Coco           8660
# Eclairs                 8757
# Fruit & Nut Bars        7738
# Manuka Honey Choco      7781
# Milk Bars               8330
# Mint Chip Choco         8207
# Orange Choco            7732
# Organic Choco Syrup     7749
# Peanut Butter Cubes     8304
# Raspberry Choco         7115
# Smooth Sliky Salty      8810
# Spicy Special Slims     8685
# White Choc              8240
# Name: Boxes Shipped, dtype: int64

# %%
df.groupby('Product')['Boxes Shipped'].sum().max()
# Out:
# 9792

# %% [markdown]
# **50% Dark Bites is the most shipped product**

# %%
df.groupby('Product')['Amount'].sum()
# Out:
# Product
# 50% Dark Bites          341712
# 70% Dark Bites          211610
# 85% Dark Bars           299229
# 99% Dark & Pure         299796
# After Nines             261331
# Almond Choco            277536
# Baker's Choco Chips     249613
# Caramel Stuffed Bars    231588
# Choco Coated Almonds    241486
# Drinking Coco           256655
# Eclairs                 312445
# Fruit & Nut Bars        259147
# Manuka Honey Choco      275541
# Milk Bars               269248
# Mint Chip Choco         283969
# Orange Choco            256144
# Organic Choco Syrup     294700
# Peanut Butter Cubes     324842
# Raspberry Choco         264740
# Smooth Sliky Salty      349692
# Spicy Special Slims     293454
# White Choc              329147
# Name: Amount, dtype: int64

# %%
df.groupby('Product')['Amount'].sum().max()
# Out:
# 349692

# %%
df.groupby('Product')['Amount'].sum() == df.groupby('Product')['Amount'].sum().max()
# Out:
# Product
# 50% Dark Bites          False
# 70% Dark Bites          False
# 85% Dark Bars           False
# 99% Dark & Pure         False
# After Nines             False
# Almond Choco            False
# Baker's Choco Chips     False
# Caramel Stuffed Bars    False
# Choco Coated Almonds    False
# Drinking Coco           False
# Eclairs                 False
# Fruit & Nut Bars        False
# Manuka Honey Choco      False
# Milk Bars               False
# Mint Chip Choco         False
# Orange Choco            False
# Organic Choco Syrup     False
# Peanut Butter Cubes     False
# Raspberry Choco         False
# Smooth Sliky Salty       True
# Spicy Special Slims     False
# White Choc              False
# Name: Amount, dtype: bool

# %% [markdown]
# **We could've just skipped to this process. Create a boolean series then pick whichever's true.**
# **In this case, it's Smooth Sliky Salty**

# %% [markdown]
# **Alse the best seller with respect to Amount**
# Wrong answer

# %% [markdown]
# **Answer = Smooth Silky Salty**

# %% [markdown]
# ## Top Sales Person.

# %%
df.head(2)
# Out:
#      Sales Person Country          Product       Date  Amount  Boxes Shipped  \
# 0  Jehu Rudeforth      UK  Mint Chip Choco 2022-01-04    5320            180
# 1     Van Tuxwell   India    85% Dark Bars 2022-08-01    7896             94
#
#      Currency  Amount Per Box
# 0  Dollars($)       29.555556
# 1  Dollars($)       84.000000

# %%
df.groupby('Sales Person')['Amount'].sum() == df.groupby('Sales Person')['Amount'].sum().max()
# Out:
# Sales Person
# Andria Kimpton         False
# Barr Faughny           False
# Beverie Moffet         False
# Brien Boise            False
# Camilla Castle         False
# Ches Bonnell            True
# Curtice Advani         False
# Dennison Crosswaite    False
# Dotty Strutley         False
# Gigi Bohling           False
# Gunar Cockshoot        False
# Husein Augar           False
# Jan Morforth           False
# Jehu Rudeforth         False
# Kaine Padly            False
# Karlen McCaffrey       False
# Kelci Walkden          False
# Madelene Upcott        False
# Mallorie Waber         False
# Marney O'Breen         False
# Oby Sorrel             False
# Rafaelita Blaksland    False
# Roddy Speechley        False
# Van Tuxwell            False
# Wilone O'Kielt         False
# Name: Amount, dtype: bool

# %% [markdown]
# **Ches Bonnel has the most sales.**

# %%
df.groupby('Sales Person')['Boxes Shipped'].sum() == df.groupby('Sales Person')['Boxes Shipped'].sum().max()
# Out:
# Sales Person
# Andria Kimpton         False
# Barr Faughny           False
# Beverie Moffet         False
# Brien Boise            False
# Camilla Castle         False
# Ches Bonnell           False
# Curtice Advani         False
# Dennison Crosswaite    False
# Dotty Strutley         False
# Gigi Bohling           False
# Gunar Cockshoot        False
# Husein Augar           False
# Jan Morforth           False
# Jehu Rudeforth         False
# Kaine Padly            False
# Karlen McCaffrey        True
# Kelci Walkden          False
# Madelene Upcott        False
# Mallorie Waber         False
# Marney O'Breen         False
# Oby Sorrel             False
# Rafaelita Blaksland    False
# Roddy Speechley        False
# Van Tuxwell            False
# Wilone O'Kielt         False
# Name: Boxes Shipped, dtype: bool

# %% [markdown]
# **Karleb McCaffrey has the most Shipments**

# %% [markdown]
# ## Boss wants us to check sales over time. Amount sold per Month

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency  Amount Per Box
# 0            180  Dollars($)       29.555556
# 1             94  Dollars($)       84.000000
# 2             91  Dollars($)       49.461538
# 3            342  Dollars($)       37.210526
# 4            184  Dollars($)       74.375000

# %%
from datetime import datetime

# %%
def extmonth (date):
    date.dt.to_period('M')

# %%
df['Month'] = df['Date'].dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency  Amount Per Box       Month
# 0            180  Dollars($)       29.555556  2022-01-04
# 1             94  Dollars($)       84.000000  2022-08-01
# 2             91  Dollars($)       49.461538  2022-07-07
# 3            342  Dollars($)       37.210526  2022-04-27
# 4            184  Dollars($)       74.375000  2022-02-24

# %%
df['Month'] = df['Date'].apply(lambda x: str(x))
#Convert dates from Date to strings.

# %%
df.dtypes
# Out:
# Sales Person              object
# Country                   object
# Product                   object
# Date              datetime64[ns]
# Amount                     int64
# Boxes Shipped              int64
# Currency                  object
# Amount Per Box           float64
# Month                     object
# dtype: object

# %%
# we split the strings by ('-'), which gave us a list

# %%
df['Month'] = df['Month'].apply(lambda x: x[1])
#After running the split and checking it worked, we extract the second value in the list(which is month a.k.a position 1)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency  Amount Per Box Month
# 0            180  Dollars($)       29.555556    01
# 1             94  Dollars($)       84.000000    08
# 2             91  Dollars($)       49.461538    07
# 3            342  Dollars($)       37.210526    04
# 4            184  Dollars($)       74.375000    02

# %% [markdown]
# **Now we plot by month**

# %%
sns.barplot(x='Month',y='Amount',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Amount'>

# %% [markdown]
# ## Boss wants the average amount sold by product in each country

# %%
ptable = df.pivot_table(index='Country',columns='Product',values='Amount')

# %%
ptable
# Out:
# Product      50% Dark Bites  70% Dark Bites  85% Dark Bars  99% Dark & Pure  \
# Country
# Australia       5576.375000     4372.666667    4809.875000      4991.636364
# Canada          7519.166667     7378.000000    6321.000000      7366.333333
# India           8068.375000     4959.000000    6292.222222      5240.375000
# New Zealand     5042.000000     6204.333333    5629.166667      6354.600000
# UK              4174.333333     3452.166667    6907.833333      7190.909091
# USA             5222.000000     3430.000000    6355.222222      5986.750000
#
# Product      After Nines  Almond Choco  Baker's Choco Chips  \
# Country
# Australia    3967.000000   4261.727273          6478.111111
# Canada       5999.000000   5253.500000          7291.200000
# India        5875.800000   5646.666667          5502.000000
# New Zealand  4641.583333   5842.200000          5738.250000
# UK           6904.800000   7493.500000          4335.333333
# USA          4732.000000   6950.000000          8484.000000
#
# Product      Caramel Stuffed Bars  Choco Coated Almonds  Drinking Coco  ...  \
# Country                                                                 ...
# Australia             5707.000000           6224.166667    4349.916667  ...
# Canada                5562.666667           5746.300000    5329.333333  ...
# India                 3936.333333           3994.000000    5736.500000  ...
# New Zealand           5668.833333           6962.666667    5192.833333  ...
# UK                    5692.555556           6232.333333    3448.666667  ...
# USA                   6265.000000          10435.250000    4228.777778  ...
#
# Product      Manuka Honey Choco    Milk Bars  Mint Chip Choco  Orange Choco  \
# Country
# Australia           5746.125000  5561.181818          7243.00   7464.625000
# Canada              6323.625000  5961.000000          3886.75   6394.500000
# India               4690.000000  4034.333333          6915.30   3317.000000
# New Zealand         6236.125000  6142.500000          6193.50   4394.000000
# UK                  5325.250000  6337.333333          4256.00   7042.000000
# USA                 7525.777778  4825.100000          9080.75   4458.363636
#
# Product      Organic Choco Syrup  Peanut Butter Cubes  Raspberry Choco  \
# Country
# Australia            5037.083333          6842.500000      4802.636364
# Canada               3663.100000          6218.100000      2145.500000
# India                8509.375000          8545.444444      5643.000000
# New Zealand          5307.400000          3921.750000      4656.000000
# UK                   4214.000000          8855.000000      7236.833333
# USA                  8531.833333          4804.000000      7593.090909
#
# Product      Smooth Sliky Salty  Spicy Special Slims   White Choc
# Country
# Australia           5658.625000          7625.625000  5216.909091
# Canada              5688.083333          5277.363636  5121.666667
# India               6912.818182          5392.500000  4698.000000
# New Zealand         4333.777778          4515.875000  6430.666667
# UK                  6875.272727          7512.400000  5640.250000
# USA                 5686.625000          3151.750000  6722.100000
#
# [6 rows x 22 columns]

# %%
product_by_box=df.groupby(['Product', 'Country'])['Amount Per Box'].mean()

# %%
pbb = pd.DataFrame(product_by_box)

# %%
pbb
# Out:
#                             Amount Per Box
# Product        Country
# 50% Dark Bites Australia        161.783575
#                Canada            96.850460
#                India            234.781219
#                New Zealand       97.948238
#                UK                41.009846
# ...                                    ...
# White Choc     Canada           764.283434
#                India             21.672790
#                New Zealand      178.981128
#                UK                51.662733
#                USA              341.191527
#
# [132 rows x 1 columns]

# %%
pbb.sort_values(by='Amount Per Box',ascending=False).head(10)
# Out:
#                                   Amount Per Box
# Product              Country
# White Choc           Canada           764.283434
# Mint Chip Choco      UK               545.535352
# Choco Coated Almonds USA              473.712092
# Orange Choco         UK               413.363788
# Fruit & Nut Bars     New Zealand      342.234793
# White Choc           USA              341.191527
# 99% Dark & Pure      Canada           330.491611
# Eclairs              Australia        324.847192
# 99% Dark & Pure      USA              284.479091
# 85% Dark Bars        UK               251.946488

# %% [markdown]
# ## Let's—on the side—calculate the countries business is doing well, as well as the products that do well in said countries

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped    Currency  Amount Per Box Month
# 0            180  Dollars($)       29.555556    01
# 1             94  Dollars($)       84.000000    08
# 2             91  Dollars($)       49.461538    07
# 3            342  Dollars($)       37.210526    04
# 4            184  Dollars($)       74.375000    02

# %%
sbc = pd.DataFrame(df.groupby(['Country', 'Product'])['Amount'].sum())

# %%
sbc
# Out:
#                                Amount
# Country   Product
# Australia 50% Dark Bites        89222
#           70% Dark Bites        39354
#           85% Dark Bars         38479
#           99% Dark & Pure       54908
#           After Nines           27769
# ...                               ...
# USA       Peanut Butter Cubes   33628
#           Raspberry Choco       83524
#           Smooth Sliky Salty    45493
#           Spicy Special Slims   25214
#           White Choc            67221
#
# [132 rows x 1 columns]

# %%
sbc.sort_values(by='Amount',ascending=False).head(10)
# Out:
#                                  Amount
# Country     Product
# Australia   50% Dark Bites        89222
# New Zealand Mint Chip Choco       86709
# USA         Raspberry Choco       83524
# UK          Peanut Butter Cubes   79695
#             99% Dark & Pure       79100
# India       Eclairs               79009
#             Peanut Butter Cubes   76909
#             Smooth Sliky Salty    76041
# UK          Smooth Sliky Salty    75628
# India       Spicy Special Slims   75495

# %%
sbcpt=sbc.pivot_table(values='Amount',index='Product',columns='Country')

# %%
sbcpt.head()
# Out:
# Country          Australia   Canada    India  New Zealand       UK      USA
# Product
# 50% Dark Bites     89222.0  45115.0  64547.0      35294.0  50092.0  57442.0
# 70% Dark Bites     39354.0  59024.0  34713.0      37226.0  20713.0  20580.0
# 85% Dark Bars      38479.0  37926.0  56630.0      67550.0  41447.0  57197.0
# 99% Dark & Pure    54908.0  44198.0  41923.0      31773.0  79100.0  47894.0
# After Nines        27769.0  41993.0  58758.0      55699.0  34524.0  42588.0

# %%
# Out:
# Country          Australia   Canada    India  New Zealand       UK      USA
# Product
# 50% Dark Bites     89222.0  45115.0  64547.0      35294.0  50092.0  57442.0
# 70% Dark Bites     39354.0  59024.0  34713.0      37226.0  20713.0  20580.0
# 85% Dark Bars      38479.0  37926.0  56630.0      67550.0  41447.0  57197.0
# 99% Dark & Pure    54908.0  44198.0  41923.0      31773.0  79100.0  47894.0
# After Nines        27769.0  41993.0  58758.0      55699.0  34524.0  42588.0
